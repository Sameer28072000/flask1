# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
Ans:-Flask is a lightweight and flexible web framework for Python. 
      It is designed to be simple, yet powerful, providing the essentials needed to build web applications.
    
    Advantages of Flask Framework:-
      i.Light weight easy to learn
        ii.Flexibility
          iii.Routing & URL mapping
            iv.Templating
              v.Testing support

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Flask.jpg](attachment:0cd4e243-4d60-456f-8188-ce318b7051c6.jpg)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %%
Ans:-In Flask, app routing refers to the process of mapping URL patterns to
         specific functions or view handlers within the application.
    
    Use of app routes:-
      i.Request Handling
        ii.URL structure
          iii.View dispatching
            iv.Seperation of concern
              v.Code organization

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/company_details')
def company_details():
    company_name = 'ABC Corporation'
    location = 'India'
    contact_detail = '999-999-9999'

    return f'''
    <h1>Company Details</h1>
    <p>Company Name: {company_name}</p>
    <p>Location: {location}</p>
    <p>Contact Detail: {contact_detail}</p>
    '''
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![welcome.jpg](attachment:5752defd-0a53-4bac-9a06-efd856391902.jpg)

# %% [markdown]
# ![company details.jpg](attachment:4b58a8c2-8e54-4585-9d19-1d1bb90a7b96.jpg)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %%
Ans:-In Flask, the url_for() function is used for URL building. 
       It generates a URL for a specific endpoint based on the provided endpoint name and any additional parameters.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Home Page'

@app.route('/user/<username>')
def profile(username):
    return f'Profile Page of {username}'

@app.route('/post/<int:post_id>')
def post(post_id):
    return f'Post {post_id}'

@app.route('/dashboard')
def dashboard():
    # Generating URLs using url_for()
    home_url = url_for('home')
    profile_url = url_for('profile', username='john')
    post_url = url_for('post', post_id=5)

    return f'''
    <p>Home URL: {home_url}</p>
    <p>Profile URL: {profile_url}</p>
    <p>Post URL: {post_url}</p>
    '''

if __name__ == '__main__':
    app.run()

# %%
Home URL: /
Profile URL: /user/john
Post URL: /post/5
